# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
from dataprep.eda import create_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/life_expectancy_data.csv")

# %% [markdown]
# ## Explore life expectancy trends

# %%
a = df.groupby(['Year','Status']).mean()["Life expectancy "]

year = []
developed = []
life = []

y = 2000
sum = 0

for i in a:
    if(sum % 2 != 0):
        year.append(y)
        developed.append("Developing")
        life.append(i)
    else:
        year.append(y)
        y = y + 1
        developed.append("Developed")
        life.append(i)
    sum = sum + 1

a = pd.DataFrame(list(zip(year, developed, life)), columns= ['Year', "Status", 'Life Expectancy'])

sns.relplot(
    data=a, kind="line",
    x="Year", y="Life Expectancy", hue="Status")
plt.show()

# %% [markdown]
# ### Basic Cleaning

# %%
from dataprep.clean import clean_headers, clean_country

df = clean_headers(df)
df = clean_country(df, "country")
df["developed"] = np.where(df["status"] == "Developed", 1, 0)
df["country"] = df["country_clean"]
df.insert(df.shape[1]-1, 'life_expectancy', df.pop('life_expectancy'))
df.drop(columns=['status', 'country_clean'], inplace= True)

df
# Out:
# Column Headers Cleaning Report:
# 	22 values cleaned (100.0%)
#   0%|          | 0/9 [00:00<?, ?it/s]
# Country Cleaning Report:
# 	369 values cleaned (12.56%)
# Result contains 2938 (100.0%) values in the correct format and 0 null values (0.0%)
#           country  year  adult_mortality  infant_deaths  alcohol  \
# 0     Afghanistan  2015            263.0             62     0.01
# 1     Afghanistan  2014            271.0             64     0.01
# 2     Afghanistan  2013            268.0             66     0.01
# 3     Afghanistan  2012            272.0             69     0.01
# 4     Afghanistan  2011            275.0             71     0.01
# ...           ...   ...              ...            ...      ...
# 2933     Zimbabwe  2004            723.0             27     4.36
# 2934     Zimbabwe  2003            715.0             26     4.06
# 2935     Zimbabwe  2002             73.0             25     4.43
# 2936     Zimbabwe  2001            686.0             25     1.72
# 2937     Zimbabwe  2000            665.0             24     1.68
#
#       percentage_expenditure  hepatitis_b  measles   bmi  under_five_deaths  \
# 0                  71.279624         65.0     1154  19.1                 83
# 1                  73.523582         62.0      492  18.6                 86
# 2                  73.219243         64.0      430  18.1                 89
# 3                  78.184215         67.0     2787  17.6                 93
# 4                   7.097109         68.0     3013  17.2                 97
# ...                      ...          ...      ...   ...                ...
# 2933                0.000000         68.0       31  27.1                 42
# 2934                0.000000          7.0      998  26.7                 41
# 2935                0.000000         73.0      304  26.3                 40
# 2936                0.000000         76.0      529  25.9                 39
# 2937                0.000000         79.0     1483  25.5                 39
#
#       ...  diphtheria  hiv_aids         gdp  population  thinness_1_19_years  \
# 0     ...        65.0       0.1  584.259210  33736494.0                 17.2
# 1     ...        62.0       0.1  612.696514    327582.0                 17.5
# 2     ...        64.0       0.1  631.744976  31731688.0                 17.7
# 3     ...        67.0       0.1  669.959000   3696958.0                 17.9
# 4     ...        68.0       0.1   63.537231   2978599.0                 18.2
# ...   ...         ...       ...         ...         ...                  ...
# 2933  ...        65.0      33.6  454.366654  12777511.0                  9.4
# 2934  ...        68.0      36.7  453.351155  12633897.0                  9.8
# 2935  ...        71.0      39.8   57.348340    125525.0                  1.2
# 2936  ...        75.0      42.1  548.587312  12366165.0                  1.6
# 2937  ...        78.0      43.5  547.358878  12222251.0                 11.0
#
#       thinness_5_9_years  income_composition_of_resources  schooling  \
# 0                   17.3                            0.479       10.1
# 1                   17.5                            0.476       10.0
# 2                   17.7                            0.470        9.9
# 3                   18.0                            0.463        9.8
# 4                   18.2                            0.454        9.5
# ...                  ...                              ...        ...
# 2933                 9.4                            0.407        9.2
# 2934                 9.9                            0.418        9.5
# 2935                 1.3                            0.427       10.0
# 2936                 1.7                            0.427        9.8
# 2937                11.2                            0.434        9.8
#
#       developed  life_expectancy
# 0             0             65.0
# 1             0             59.9
# 2             0             59.9
# 3             0             59.5
# 4             0             59.2
# ...         ...              ...
# 2933          0             44.3
# 2934          0             44.5
# 2935          0             44.8
# 2936          0             45.3
# 2937          0             46.0
#
# [2938 rows x 22 columns]

# %% [markdown]
# # Preprocessing
# ### EDA

# %%
report = create_report(df)
report.show_browser()
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]

# %% [markdown]
# ## Missing Values
# ### Identify missing values
# 1. infant deaths: if a developing country has a value of 0 or if the value is larger than 1000
# 2. percentage expenditure: has a value of 0
# 3. measles: if a developing country has a value of 0 or if the value is larger than 1000
# 4. under-five deaths: if a developing country has a value of 0 or if the value is larger than 1000
#
# ### Drop samples missing y
# - 10 entry's life expectancy is missing, drop them

# %%
nan = np.nan

# 1
df['infant_deaths'].mask( (df['infant_deaths'] > 1000) | ((df['infant_deaths'] == 0) & (df["developed"] == 0)), nan, inplace=True)

# 2
df['percentage_expenditure'].mask( df['percentage_expenditure'] == 0, nan, inplace=True)

# 3
df['measles'].mask( (df['measles'] > 1000) | ((df['measles'] == 0) & (df["developed"] == 0)), nan, inplace=True)

# 4
df['under_five_deaths'].mask( (df['under_five_deaths'] > 1000) | ((df['under_five_deaths'] == 0) & (df["developed"] == 0)), nan, inplace=True)

# 5
df.dropna(subset=['life_expectancy'], inplace=True)

df
# Out:
#           country  year  adult_mortality  infant_deaths  alcohol  \
# 0     Afghanistan  2015            263.0           62.0     0.01
# 1     Afghanistan  2014            271.0           64.0     0.01
# 2     Afghanistan  2013            268.0           66.0     0.01
# 3     Afghanistan  2012            272.0           69.0     0.01
# 4     Afghanistan  2011            275.0           71.0     0.01
# ...           ...   ...              ...            ...      ...
# 2933     Zimbabwe  2004            723.0           27.0     4.36
# 2934     Zimbabwe  2003            715.0           26.0     4.06
# 2935     Zimbabwe  2002             73.0           25.0     4.43
# 2936     Zimbabwe  2001            686.0           25.0     1.72
# 2937     Zimbabwe  2000            665.0           24.0     1.68
#
#       percentage_expenditure  hepatitis_b  measles   bmi  under_five_deaths  \
# 0                  71.279624         65.0      NaN  19.1               83.0
# 1                  73.523582         62.0    492.0  18.6               86.0
# 2                  73.219243         64.0    430.0  18.1               89.0
# 3                  78.184215         67.0      NaN  17.6               93.0
# 4                   7.097109         68.0      NaN  17.2               97.0
# ...                      ...          ...      ...   ...                ...
# 2933                     NaN         68.0     31.0  27.1               42.0
# 2934                     NaN          7.0    998.0  26.7               41.0
# 2935                     NaN         73.0    304.0  26.3               40.0
# 2936                     NaN         76.0    529.0  25.9               39.0
# 2937                     NaN         79.0      NaN  25.5               39.0
#
#       ...  diphtheria  hiv_aids         gdp  population  thinness_1_19_years  \
# 0     ...        65.0       0.1  584.259210  33736494.0                 17.2
# 1     ...        62.0       0.1  612.696514    327582.0                 17.5
# 2     ...        64.0       0.1  631.744976  31731688.0                 17.7
# 3     ...        67.0       0.1  669.959000   3696958.0                 17.9
# 4     ...        68.0       0.1   63.537231   2978599.0                 18.2
# ...   ...         ...       ...         ...         ...                  ...
# 2933  ...        65.0      33.6  454.366654  12777511.0                  9.4
# 2934  ...        68.0      36.7  453.351155  12633897.0                  9.8
# 2935  ...        71.0      39.8   57.348340    125525.0                  1.2
# 2936  ...        75.0      42.1  548.587312  12366165.0                  1.6
# 2937  ...        78.0      43.5  547.358878  12222251.0                 11.0
#
#       thinness_5_9_years  income_composition_of_resources  schooling  \
# 0                   17.3                            0.479       10.1
# 1                   17.5                            0.476       10.0
# 2                   17.7                            0.470        9.9
# 3                   18.0                            0.463        9.8
# 4                   18.2                            0.454        9.5
# ...                  ...                              ...        ...
# 2933                 9.4                            0.407        9.2
# 2934                 9.9                            0.418        9.5
# 2935                 1.3                            0.427       10.0
# 2936                 1.7                            0.427        9.8
# 2937                11.2                            0.434        9.8
#
#       developed  life_expectancy
# 0             0             65.0
# 1             0             59.9
# 2             0             59.9
# 3             0             59.5
# 4             0             59.2
# ...         ...              ...
# 2933          0             44.3
# 2934          0             44.5
# 2935          0             44.8
# 2936          0             45.3
# 2937          0             46.0
#
# [2928 rows x 22 columns]

# %%
report = create_report(df)
report.show_browser()

# %%
df.drop(columns=["under_five_deaths", "percentage_expenditure", "thinness_5_9_years", "income_composition_of_resources"], inplace=True)

# %% [markdown]
# # Impute missing values

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Split
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['life_expectancy', "country"]), df[["country",'life_expectancy']], test_size=0.3, random_state=0)

col = x_train.columns

# %%
# Scaling
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = pd.DataFrame(scaler.transform(x_train))
x_test = pd.DataFrame(scaler.transform(x_test))

# Imputation
imputer = KNNImputer(n_neighbors=16, weights="uniform")
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
x_train = pd.DataFrame(x_train,
                   columns=col)
x_test = pd.DataFrame(x_test,
                   columns=col)

# %% [markdown]
# ## Data after preprocessing

# %%
report = create_report(x_train)
report.show_browser()
# Out:
#   0%|          | 0/3289 [00:00<?, ?it/s]

# %% [markdown]
# # Model Training
# ## Base Line -- linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

regr = LinearRegression().fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_train)
a = mean_squared_error(y_train["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_train["life_expectancy"], yHat)
print(a)


yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 4.099259245625784
# 0.8132764115068367
# 4.063549203665026
# 0.8209656479737294

# %%
from matplotlib import pyplot
# get importance
importance = regr.coef_
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %s, Score: %.5f' % (col[i],v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: year, Score: -0.07551
# Feature: adult_mortality, Score: -13.29826
# Feature: infant_deaths, Score: -5.72947
# Feature: alcohol, Score: -0.14895
# Feature: hepatitis_b, Score: -0.26540
# Feature: measles, Score: -0.29861
# Feature: bmi, Score: 2.57963
# Feature: polio, Score: 2.91189
# Feature: total_expenditure, Score: 0.36457
# Feature: diphtheria, Score: 3.56658
# Feature: hiv_aids, Score: -25.14655
# Feature: gdp, Score: 7.24823
# Feature: population, Score: 3.21744
# Feature: thinness_1_19_years, Score: -2.11049
# Feature: schooling, Score: 21.69752
# Feature: developed, Score: 1.21266

# %% [markdown]
# ## LR with Regularization

# %%
from sklearn import linear_model

for i in [0.5, 0.3, 0.1, 0.01, 0.001]:
    regr = linear_model.Lasso(alpha=i).fit(x_train, y_train["life_expectancy"])

# for i in [0, 1, 2, 3, 4, 5, 10]:
#     regr = linear_model.Ridge(alpha=i).fit(x_train, y_train["life_expectancy"])

    yHat = regr.predict(x_test)
    a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
    print(a)
    a = r2_score(y_test["life_expectancy"], yHat)
    print(a)
# Out:
# 5.923678380438476
# 0.6195406469470681
# 5.129870458448461
# 0.7146761209565543
# 4.270137980469661
# 0.8022988751535303
# 4.068013773989096
# 0.8205720262840804
# 4.063472696611162
# 0.8209723895000074

# %%
regr = linear_model.Lasso(alpha=0.1).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)

# get importance
importance = regr.coef_
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %s, Score: %.5f' % (col[i],v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# 4.270137980469661
# 0.8022988751535303
# Feature: year, Score: 0.00000
# Feature: adult_mortality, Score: -14.18805
# Feature: infant_deaths, Score: -0.00000
# Feature: alcohol, Score: 0.00000
# Feature: hepatitis_b, Score: 0.00000
# Feature: measles, Score: -0.00000
# Feature: bmi, Score: 3.81465
# Feature: polio, Score: 2.66524
# Feature: total_expenditure, Score: 0.00000
# Feature: diphtheria, Score: 3.34105
# Feature: hiv_aids, Score: -16.31398
# Feature: gdp, Score: 0.27523
# Feature: population, Score: -0.00000
# Feature: thinness_1_19_years, Score: -0.00114
# Feature: schooling, Score: 20.30099
# Feature: developed, Score: 2.43886

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(max_depth=10, random_state=0).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 2.1064671293188324
# 0.951890073192603

# %%
from sklearn.model_selection import GridSearchCV

regr = GridSearchCV(
    RandomForestRegressor(),
    [{'n_estimators': range(100, 600, 100), 'max_depth': range(3, 15, 4), 'min_samples_leaf':  range(5, 40, 10)}], cv=10, scoring='r2')
regr.fit(x_train, y_train['life_expectancy'])


results = pd.DataFrame(regr.cv_results_)
results.sort_values(by='rank_test_score', inplace=True)


print(regr.best_params_)
# Out:
# {'max_depth': 11, 'min_samples_leaf': 5, 'n_estimators': 500}

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
#
# 53              11                     25                400
# 52              11                     25                300
# 51              11                     25                200
# 50              11                     25                100
# 30               7                     25                100
# 33               7                     25                400
# 34               7                     25                500
# 31               7                     25                200
# 32               7                     25                300
# 55              11                     35                100
# 57              11                     35                300
# 58              11                     35                400
# 56              11                     35                200
# 59              11                     35                500
# 37               7                     35                300
# 39               7                     35                500
# 38               7                     35                400
# 36               7                     35                200
# 35               7                     35                100
# 5                3                     15                100
# 12               3                     25                300
# 7                3                     15                300
# 1                3                      5                200
# 9                3                     15                500
# 11               3                     25                200
# 3                3                      5                400
# 6                3                     15                200
# 8                3                     15                400
# 14               3                     25                500
# 4                3                      5                500
# 13               3                     25                400
# 10               3                     25                100
# 0                3                      5                100
# 2                3                      5                300
# 16               3                     35                200
# 19               3                     35                500
# 17               3                     35                300
# 18               3                     35                400
# 15               3                     35                100
#
#                                                params  split0_test_score  \
# 44  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.952234
# 42  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.951647
# 41  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.951162
# 43  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.951127
# 40  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.951743
# 22  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.941158
# 20  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.940360
# 24  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.941511
# 23  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.940760
# 21  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.941538
# 48  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.938951
# 49  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.937740
# 46  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.938241
# 45  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.937911
# 47  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.938394
# 26  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.933842
# 28  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.932842
# 27  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.933397
# 29  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.933221
# 25  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.932559
# 54  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.927928
# 53  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.928193
# 52  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.927698
# 51  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.928259
# 50  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.927368
# 30  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.926277
# 33  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.925055
# 34  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.926671
# 31  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.925802
# 32  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.926281
# 55  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.916103
# 57  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.915933
# 58  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.916037
# 56  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.916315
# 59  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.915773
# 37  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.915062
# 39  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.915023
# 38  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.915338
# 36  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.915130
# 35  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.915039
# 5   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.857101
# 12  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.858214
# 7   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.858181
# 1   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.859843
# 9   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.858144
# 11  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.856169
# 3   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.859163
# 6   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.859287
# 8   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.859934
# 14  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.857021
# 4   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.858045
# 13  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.858041
# 10  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.857161
# 0   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.859500
# 2   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.858765
# 16  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.857015
# 19  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.857438
# 17  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.856092
# 18  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.856100
# 15  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.855457
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 44           0.959358  ...           0.947196           0.951875
# 42           0.958862  ...           0.948125           0.951998
# 41           0.958406  ...           0.947674           0.950941
# 43           0.959775  ...           0.947992           0.951617
# 40           0.959503  ...           0.946879           0.951355
# 22           0.947243  ...           0.935915           0.940558
# 20           0.950553  ...           0.934568           0.941477
# 24           0.948844  ...           0.934855           0.940730
# 23           0.947922  ...           0.936719           0.939877
# 21           0.947461  ...           0.935674           0.940232
# 48           0.944497  ...           0.932198           0.934441
# 49           0.944682  ...           0.931677           0.933494
# 46           0.943649  ...           0.932869           0.933105
# 45           0.942094  ...           0.932562           0.930892
# 47           0.943527  ...           0.931309           0.934809
# 26           0.939044  ...           0.925834           0.928106
# 28           0.938554  ...           0.927225           0.927927
# 27           0.938202  ...           0.926224           0.928467
# 29           0.938210  ...           0.926659           0.927473
# 25           0.937988  ...           0.924641           0.928557
# 54           0.928909  ...           0.917146           0.915465
# 53           0.928718  ...           0.917721           0.914839
# 52           0.928833  ...           0.916728           0.916083
# 51           0.928272  ...           0.916283           0.915931
# 3            0.845443           0.836538         0.845087        0.010939
# 6            0.845884           0.834807         0.844992        0.011793
# 8            0.845156           0.835247         0.844961        0.011181
# 14           0.843685           0.836707         0.844955        0.011267
# 4            0.843090           0.835425         0.844895        0.011116
# 13           0.842616           0.836338         0.844547        0.010713
# 10           0.843666           0.838356         0.844339        0.010743
# 0            0.842826           0.834092         0.844153        0.011758
# 2            0.841488           0.837340         0.844114        0.011084
# 16           0.838693           0.833897         0.843582        0.010713
# 19           0.838216           0.835450         0.843487        0.010918
# 17           0.840177           0.835596         0.842702        0.011669
# 18           0.840207           0.831707         0.842655        0.011640
# 15           0.842266           0.835710         0.842420        0.011484
#
#     rank_test_score
# 44                1
# 42                2
# 41                3
# 43                4
# 40                5
# 22                6
# 20                7
# 24                8
# 23                9
# 21               10
# 48               11
# 49               12
# 46               13
# 45               14
# 47               15
# 26               16
# 28               17
# 27               18
# 29               19
# 25               20
# 54               21
# 53               22
# 52               23
# 51               24
# 50               25
# 30               26
# 33               27
# 34               28
# 31               29
# 32               30
# 55               31
# 57               32
# 58               33
# 56               34
# 59               35
# 37               36
# 39               37
# 38               38
# 36               39
# 35               40
# 5                41
# 12               42
# 7                43
# 1                44
# 9                45
# 11               46
# 3                47
# 6                48
# 8                49
# 14               50
# 4                51
# 13               52
# 10               53
# 0                54
# 2                55
# 16               56
# 19               57
# 17               58
# 18               59
# 15               60
#
# [60 rows x 21 columns]

# %%
regr = RandomForestRegressor(max_depth=11, min_samples_leaf=5, n_estimators=500, random_state=0).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 2.1706104390516696
# 0.9489155057843789

# %%
import matplotlib.pyplot as plt

importances = regr.feature_importances_
std = np.std([tree.feature_importances_ for tree in regr.estimators_], axis=0)

forest_importances = pd.Series(importances, index=col)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## XGboost

# %%
import xgboost as xg

# Instantiation
xgb_r = xg.XGBRegressor(objective ='reg:squarederror',
                  n_estimators = 10, seed = 123)

# Fitting the model
xgb_r.fit(x_train, y_train["life_expectancy"])

# Predict the model
pred = xgb_r.predict(x_test)

mse = mean_squared_error(y_test["life_expectancy"], pred)**(0.5)
print(mse)
a = r2_score(y_test["life_expectancy"], pred)
print(a)
# Out:
# 3.3224281217386196
# 0.8803158853940382

# %%
def hyperParameterTuning(X_train, y_train):
    param_tuning = {
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5, 7, 10],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.5, 0.7],
        'colsample_bytree': [0.5, 0.7],
        'n_estimators' : [100, 200, 500],
        'objective': ['reg:squarederror']
    }

    xgb_model = xg.XGBRegressor()

    gsearch = GridSearchCV(estimator = xgb_model,
                           param_grid = param_tuning,
                           #scoring = 'neg_mean_absolute_error', #MAE
                           #scoring = 'neg_mean_squared_error',  #MSE
                           cv = 10,
                           n_jobs = -1,
                           verbose = 1)

    gsearch.fit(X_train,y_train)


    results_xg = pd.DataFrame(gsearch.cv_results_)
    results_xg.sort_values(by='rank_test_score', inplace=True)

    return gsearch.best_params_

# %%
hyperParameterTuning(x_train, y_train['life_expectancy'])
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.1,
#  'max_depth': 7,
#  'min_child_weight': 3,
#  'n_estimators': 500,
#  'objective': 'reg:squarederror',
#  'subsample': 0.7}

# %%
# Instantiation
xgb_model = xg.XGBRegressor(
        objective = 'reg:squarederror',
        colsample_bytree = 0.7,
        learning_rate = 0.1,
        max_depth = 7,
        min_child_weight = 3,
        n_estimators = 500,
        subsample = 0.7)

# Fitting the model
xgb_model.fit(x_train, y_train["life_expectancy"], verbose=False)

# Predict the model
pred = xgb_model.predict(x_test)

mse = mean_squared_error(y_test["life_expectancy"], pred)**(0.5)
print(mse)
a = r2_score(y_test["life_expectancy"], pred)
print(a)
# Out:
# 2.072378049421742
# 0.953434605097502

# %%
from matplotlib import pyplot as plt

sorted_idx = xgb_model.feature_importances_.argsort()
plt.barh(col[sorted_idx], xgb_model.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
# Out:
# Text(0.5, 0, 'Xgboost Feature Importance')

# %% [markdown]
# # Developing Countries
# ## Preprocessing

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Split
developing_df = df.loc[df['developed'] == 0]

x_train, x_test, y_train, y_test = train_test_split(developing_df.drop(columns=['life_expectancy', "country",'developed']), developing_df[["country",'life_expectancy']], test_size=0.3, random_state=0)

col = x_train.columns

# Scaling
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = pd.DataFrame(scaler.transform(x_train))
x_test = pd.DataFrame(scaler.transform(x_test))

# Imputation
imputer = KNNImputer(n_neighbors=16, weights="uniform")
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

x_train = pd.DataFrame(x_train,
                   columns=col)
x_test = pd.DataFrame(x_test,
                   columns=col)

# %%
report = create_report(x_train)
report.show_browser()
# Out:
#   0%|          | 0/3194 [00:00<?, ?it/s]

# %%
x_train
# Out:
#           year  adult_mortality  infant_deaths   alcohol  hepatitis_b  \
# 0     0.666667         0.118715       0.002200  0.654535     0.653061
# 1     0.666667         0.405028       0.030803  0.010638     0.642857
# 2     0.466667         0.617318       0.066007  0.143897     0.765306
# 3     0.200000         0.055866       0.622662  0.545353     0.447704
# 4     0.066667         0.053073       0.045105  0.082867     0.592474
# ...        ...              ...            ...       ...          ...
# 1686  0.400000         0.265363       0.173817  0.002800     0.663265
# 1687  0.800000         0.243017       0.000000  0.597424     0.948980
# 1688  0.266667         0.493017       0.237624  0.047592     0.287628
# 1689  0.800000         0.374302       0.002200  0.000000     0.989796
# 1690  0.666667         0.210894       0.002200  0.315789     0.897959
#
#        measles       bmi     polio  total_expenditure  diphtheria  hiv_aids  \
# 0     0.090994  0.066580  1.000000           0.804606    1.000000  0.000000
# 1     0.044088  0.023499  0.614583           0.310550    0.639175  0.041584
# 2     0.004008  0.289817  0.750000           0.444279    0.762887  0.102970
# 3     0.242673  0.225849  0.406250           0.306835    0.278351  0.104950
# 4     0.353958  0.014360  0.812500           0.236999    0.793814  0.067327
# ...        ...       ...       ...                ...         ...       ...
# 1686  0.217310  0.244125  0.781250           0.188707    0.721649  0.000000
# 1687  0.010020  0.659269  0.927083           0.854383    0.927835  0.000000
# 1688  0.072144  0.163185  0.531250           0.286776    0.020619  0.079208
# 1689  0.131889  0.318538  0.989583           0.427192    0.989691  0.025743
# 1690  0.098885  0.592689  0.854167           0.648588    0.896907  0.000000
#
#            gdp  population  thinness_1_19_years  schooling
# 0     0.005303    0.005533             0.018116   0.883978
# 1     0.004913    0.000152             0.293478   0.458564
# 2     0.005104    0.004791             0.242754   0.379144
# 3     0.005747    0.111871             0.485507   0.447514
# 4     0.003048    0.001646             0.322464   0.441989
# ...        ...         ...                  ...        ...
# 1686  0.017870    0.019483             0.061594   0.602210
# 1687  0.057475    0.012573             0.094203   0.708564
# 1688  0.001491    0.006326             0.413043   0.298343
# 1689  0.009437    0.007793             0.278986   0.486188
# 1690  0.036381    0.000534             0.072464   0.685083
#
# [1691 rows x 15 columns]

# %% [markdown]
# ## Models
# same as all data part

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

regr = LinearRegression().fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_train)
a = mean_squared_error(y_train["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_train["life_expectancy"], yHat)
print(a)


yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 4.1386769115846205
# 0.791603864306966
# 4.359957835591025
# 0.7570280746206549

# %%
from matplotlib import pyplot
# get importance
importance = regr.coef_
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %s, Score: %.5f' % (col[i],v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: year, Score: -0.43363
# Feature: adult_mortality, Score: -12.34503
# Feature: infant_deaths, Score: -5.13902
# Feature: alcohol, Score: 0.57054
# Feature: hepatitis_b, Score: -0.42306
# Feature: measles, Score: -1.02371
# Feature: bmi, Score: 3.94225
# Feature: polio, Score: 2.13437
# Feature: total_expenditure, Score: 1.32114
# Feature: diphtheria, Score: 3.74488
# Feature: hiv_aids, Score: -26.56279
# Feature: gdp, Score: 7.61561
# Feature: population, Score: -0.60532
# Feature: thinness_1_19_years, Score: 0.00502
# Feature: schooling, Score: 19.46753

# %% [markdown]
# ## LR with Regularization

# %%
from sklearn import linear_model

# for i in [0.5, 0.3, 0.1, 0.01, 0.001]:
#     regr = linear_model.Lasso(alpha=i).fit(x_train, y_train["life_expectancy"])

for i in [0, 1, 2, 3, 4, 5, 10]:
    regr = linear_model.Ridge(alpha=i).fit(x_train, y_train["life_expectancy"])

    yHat = regr.predict(x_test)
    a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
    print(a)
    a = r2_score(y_test["life_expectancy"], yHat)
    print(a)
# Out:
# 4.3599578355910245
# 0.7570280746206549
# 4.353163040366287
# 0.7577848058000486
# 4.352922540030158
# 0.7578115685130118
# 4.357233232783224
# 0.7573316533099875
# 4.364786995699189
# 0.7564895372381129
# 4.374692231464528
# 0.7553830615188536
# 4.44271476473106
# 0.7477167721875461

# %%
regr = linear_model.Ridge(alpha=2).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)

# get importance
importance = regr.coef_
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %s, Score: %.5f' % (col[i],v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# 4.352922540030158
# 0.7578115685130118
# Feature: year, Score: -0.13404
# Feature: adult_mortality, Score: -12.85499
# Feature: infant_deaths, Score: -4.26670
# Feature: alcohol, Score: 0.73949
# Feature: hepatitis_b, Score: -0.34721
# Feature: measles, Score: -1.21906
# Feature: bmi, Score: 4.41010
# Feature: polio, Score: 2.31832
# Feature: total_expenditure, Score: 0.99676
# Feature: diphtheria, Score: 3.85287
# Feature: hiv_aids, Score: -23.78126
# Feature: gdp, Score: 6.84035
# Feature: population, Score: -0.13883
# Feature: thinness_1_19_years, Score: -0.37737
# Feature: schooling, Score: 18.14733

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(max_depth=10, random_state=0).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 2.204027138857921
# 0.9379094663927023

# %%
from sklearn.model_selection import GridSearchCV

regr = GridSearchCV(
    RandomForestRegressor(),
    [{'n_estimators': range(100, 600, 100), 'max_depth': range(3, 15, 4), 'min_samples_leaf':  range(5, 40, 10)}], cv=10, scoring='r2')
regr.fit(x_train, y_train['life_expectancy'])


results = pd.DataFrame(regr.cv_results_)
results.sort_values(by='rank_test_score', inplace=True)


print(regr.best_params_)
# Out:
# {'max_depth': 11, 'min_samples_leaf': 5, 'n_estimators': 400}

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 43       2.176941      0.011618         0.021703        0.000140
# 44       2.725707      0.018118         0.027257        0.000636
# 41       1.117061      0.029579         0.012228        0.000699
# 42       1.706447      0.069677         0.017161        0.000811
# 40       0.550198      0.006205         0.006419        0.000095
# 23       1.987349      0.083295         0.040129        0.055603
# 21       0.938422      0.007843         0.010997        0.000295
# 24       2.442802      0.108835         0.026263        0.000964
# 22       1.420261      0.028171         0.015962        0.000378
# 20       0.468926      0.004547         0.006295        0.000256
# 47       1.317762      0.013469         0.015497        0.000220
# 48       1.800516      0.096870         0.020895        0.001255
# 49       2.242313      0.040362         0.025316        0.000469
# 45       0.441404      0.007607         0.005883        0.000116
# 46       0.882299      0.006325         0.010743        0.000103
# 27       1.279390      0.014013         0.015726        0.000414
# 29       2.105642      0.022692         0.024819        0.000506
# 26       0.850275      0.014401         0.010836        0.000280
# 28       1.678537      0.029229         0.020241        0.000728
# 25       0.416965      0.004071         0.006032        0.000249
# 54       2.022411      0.066005         0.025303        0.001128
# 52       1.171782      0.012317         0.015066        0.000241
# 53       1.567696      0.024754         0.035276        0.045917
# 51       0.782332      0.007824         0.010646        0.000579
# 33       1.512926      0.004466         0.019346        0.000175
# 32       1.179103      0.043510         0.018410        0.007605
# 30       0.382588      0.002992         0.006047        0.000357
# 50       0.389884      0.002554         0.005760        0.000122
# 34       1.904626      0.023426         0.024298        0.000894
# 31       0.776400      0.010990         0.010562        0.000194
# 59       1.786782      0.010894         0.024031        0.000503
# 38       1.477445      0.048617         0.019825        0.000766
# 55       0.366597      0.011768         0.005768        0.000215
# 58       1.440158      0.025621         0.019375        0.000155
# 39       1.856779      0.057695         0.024745        0.000943
# 57       1.106816      0.039862         0.015415        0.000798
# 37       1.169396      0.064234         0.018560        0.008483
# 35       0.354680      0.003097         0.005794        0.000189
# 56       0.749450      0.027490         0.010859        0.001106
# 36       0.720209      0.012686         0.010723        0.000515
# 3        0.992763      0.002510         0.017646        0.000122
# 4        1.244018      0.008317         0.021751        0.000137
# 5        0.248030      0.001234         0.005360        0.000077
# 1        0.500630      0.008511         0.009612        0.000454
# 0        0.260752      0.007371         0.005689        0.000363
# 7        0.739402      0.000945         0.013485        0.000104
# 8        0.988291      0.006797         0.017731        0.000236
# 9        1.237148      0.005745         0.021883        0.000475
# 2        0.747920      0.003290         0.013601        0.000101
# 14       1.313249      0.036183         0.023333        0.000733
# 6        0.495492      0.003412         0.009441        0.000168
# 13       1.004013      0.044773         0.018153        0.000898
# 12       0.776543      0.017588         0.014368        0.000524
# 11       0.524687      0.024566         0.010097        0.000439
# 10       0.294278      0.050550         0.008106        0.004970
# 17       0.776565      0.019881         0.014724        0.000472
# 15       0.256225      0.006170         0.005719        0.000266
# 18       1.012405      0.014636         0.018458        0.000657
# 19       1.237212      0.024797         0.022019        0.000466
# 16       0.489364      0.005664         0.009483        0.000128
#
#    param_max_depth param_min_samples_leaf param_n_estimators  \
# 43              11                      5                400
# 44              11                      5                500
# 41              11                      5                200
# 42              11                      5                300
# 40              11                      5                100
# 23               7                      5                400
# 21               7                      5                200
# 24               7                      5                500
# 22               7                      5                300
# 20               7                      5                100
# 47              11                     15                300
# 48              11                     15                400
# 49              11                     15                500
# 45              11                     15                100
# 46              11                     15                200
# 27               7                     15                300
# 29               7                     15                500
# 26               7                     15                200
# 28               7                     15                400
# 25               7                     15                100
# 54              11                     25                500
# 52              11                     25                300
# 53              11                     25                400
# 51              11                     25                200
# 33               7                     25                400
# 32               7                     25                300
# 30               7                     25                100
# 50              11                     25                100
# 34               7                     25                500
# 31               7                     25                200
# 59              11                     35                500
# 38               7                     35                400
# 55              11                     35                100
# 58              11                     35                400
# 39               7                     35                500
# 57              11                     35                300
# 37               7                     35                300
# 35               7                     35                100
# 56              11                     35                200
# 36               7                     35                200
# 3                3                      5                400
# 4                3                      5                500
# 5                3                     15                100
# 1                3                      5                200
# 0                3                      5                100
# 7                3                     15                300
# 8                3                     15                400
# 9                3                     15                500
# 2                3                      5                300
# 14               3                     25                500
# 6                3                     15                200
# 13               3                     25                400
# 12               3                     25                300
# 11               3                     25                200
# 10               3                     25                100
# 17               3                     35                300
# 15               3                     35                100
# 18               3                     35                400
# 19               3                     35                500
# 16               3                     35                200
#
#                                                params  split0_test_score  \
# 43  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.939845
# 44  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.940628
# 41  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.941136
# 42  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.939003
# 40  {'max_depth': 11, 'min_samples_leaf': 5, 'n_es...           0.939882
# 23  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.934087
# 21  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.935172
# 24  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.934142
# 22  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.934159
# 20  {'max_depth': 7, 'min_samples_leaf': 5, 'n_est...           0.934626
# 47  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.925280
# 48  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.925792
# 49  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.925114
# 45  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.923660
# 46  {'max_depth': 11, 'min_samples_leaf': 15, 'n_e...           0.924606
# 27  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.922992
# 29  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.922808
# 26  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.922253
# 28  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.923132
# 25  {'max_depth': 7, 'min_samples_leaf': 15, 'n_es...           0.921870
# 54  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.906857
# 52  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.906035
# 53  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.905706
# 51  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.903434
# 33  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.905254
# 32  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.906255
# 30  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.906265
# 50  {'max_depth': 11, 'min_samples_leaf': 25, 'n_e...           0.903186
# 34  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.905509
# 31  {'max_depth': 7, 'min_samples_leaf': 25, 'n_es...           0.904689
# 59  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.888171
# 38  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.889205
# 55  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.888035
# 58  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.888568
# 39  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.888334
# 57  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.890154
# 37  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.888211
# 35  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.887014
# 56  {'max_depth': 11, 'min_samples_leaf': 35, 'n_e...           0.888580
# 36  {'max_depth': 7, 'min_samples_leaf': 35, 'n_es...           0.886311
# 3   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.864473
# 4   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.865856
# 5   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.866342
# 1   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.864894
# 0   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.864179
# 7   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.864418
# 8   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.863857
# 9   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.865116
# 2   {'max_depth': 3, 'min_samples_leaf': 5, 'n_est...           0.865629
# 14  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.862766
# 6   {'max_depth': 3, 'min_samples_leaf': 15, 'n_es...           0.863472
# 13  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.863723
# 12  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.862542
# 11  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.863352
# 10  {'max_depth': 3, 'min_samples_leaf': 25, 'n_es...           0.862410
# 17  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.859916
# 15  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.859996
# 18  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.862019
# 19  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.862027
# 16  {'max_depth': 3, 'min_samples_leaf': 35, 'n_es...           0.862611
#
#     split1_test_score  ...  split3_test_score  split4_test_score  \
# 43           0.940508  ...           0.946056           0.932332
# 44           0.941356  ...           0.944900           0.931504
# 41           0.939944  ...           0.945209           0.931350
# 42           0.940209  ...           0.944581           0.931871
# 40           0.937911  ...           0.944236           0.931180
# 23           0.925540  ...           0.938026           0.920335
# 21           0.926147  ...           0.938015           0.918757
# 24           0.925646  ...           0.937335           0.918848
# 22           0.925739  ...           0.937287           0.920161
# 20           0.922958  ...           0.936803           0.918374
# 47           0.920343  ...           0.922078           0.910538
# 48           0.919698  ...           0.922606           0.911739
# 49           0.919106  ...           0.921390           0.910593
# 45           0.918529  ...           0.923660           0.912163
# 46           0.919204  ...           0.925331           0.911759
# 27           0.915940  ...           0.921065           0.906535
# 29           0.915111  ...           0.920429           0.906489
# 26           0.916820  ...           0.922571           0.907207
# 28           0.914116  ...           0.921450           0.907329
# 25           0.912974  ...           0.921838           0.908058
# 54           0.891042  ...           0.909244           0.882993
# 52           0.890118  ...           0.909120           0.882690
# 53           0.890217  ...           0.911831           0.884016
# 51           0.890993  ...           0.906700           0.882488
# 33           0.888096  ...           0.911293           0.882446
# 32           0.890826  ...           0.907730           0.882672
# 30           0.891436  ...           0.910218           0.880708
# 50           0.890544  ...           0.909420           0.881411
# 34           0.888718  ...           0.909519           0.881416
# 31           0.890202  ...           0.906376           0.881573
# 59           0.872719  ...           0.896476           0.867277
# 38           0.872940  ...           0.897120           0.863384
# 55           0.871615  ...           0.898195           0.867166
# 58           0.873972  ...           0.894374           0.865338
# 39           0.873140  ...           0.895123           0.864228
# 57           0.872139  ...           0.893803           0.864991
# 37           0.873218  ...           0.893227           0.863547
# 35           0.871382  ...           0.898437           0.863735
# 56           0.872091  ...           0.893640           0.865540
# 36           0.871212  ...           0.893950           0.864735
# 3            0.816944  ...           0.865697           0.824726
# 4            0.812268  ...           0.865780           0.826763
# 5            0.815001  ...           0.858531           0.832334
# 1            0.814806  ...           0.864923           0.824155
# 0            0.816608  ...           0.860026           0.824293
# 7            0.815057  ...           0.861956           0.827981
# 8            0.817774  ...           0.861294           0.827471
# 9            0.814581  ...           0.862003           0.824810
# 31               30
# 59               31
# 38               32
# 55               33
# 58               34
# 39               35
# 57               36
# 37               37
# 35               38
# 56               39
# 36               40
# 3                41
# 4                42
# 5                43
# 1                44
# 0                45
# 7                46
# 8                47
# 9                48
# 2                49
# 14               50
# 6                51
# 13               52
# 12               53
# 11               54
# 10               55
# 17               56
# 15               57
# 18               58
# 19               59
# 16               60
#
# [60 rows x 21 columns]

# %%
regr = RandomForestRegressor(max_depth=11, min_samples_leaf=5, n_estimators=400, random_state=0).fit(x_train, y_train["life_expectancy"])

yHat = regr.predict(x_test)
a = mean_squared_error(y_test["life_expectancy"], yHat)**(0.5)
print(a)
a = r2_score(y_test["life_expectancy"], yHat)
print(a)
# Out:
# 2.245102800438689
# 0.9355735829225753

# %%
import matplotlib.pyplot as plt

importances = regr.feature_importances_
std = np.std([tree.feature_importances_ for tree in regr.estimators_], axis=0)

forest_importances = pd.Series(importances, index=col)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## XGboost

# %%
import xgboost as xg

# Instantiation
xgb_r = xg.XGBRegressor(objective ='reg:squarederror',
                  n_estimators = 10, seed = 123)

# Fitting the model
xgb_r.fit(x_train, y_train["life_expectancy"])

# Predict the model
pred = xgb_r.predict(x_test)

mse = mean_squared_error(y_test["life_expectancy"], pred)**(0.5)
print(mse)
a = r2_score(y_test["life_expectancy"], pred)
print(a)
# Out:
# 3.202623815614413
# 0.8688997939429088

# %%
def hyperParameterTuning(X_train, y_train):
    param_tuning = {
        'learning_rate': [0.01, 0.1],
        'max_depth': [3, 5, 7, 10],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.5, 0.7],
        'colsample_bytree': [0.5, 0.7],
        'n_estimators' : [100, 200, 500],
        'objective': ['reg:squarederror']
    }

    xgb_model = xg.XGBRegressor()

    gsearch = GridSearchCV(estimator = xgb_model,
                           param_grid = param_tuning,
                           #scoring = 'neg_mean_absolute_error', #MAE
                           #scoring = 'neg_mean_squared_error',  #MSE
                           cv = 10,
                           n_jobs = -1,
                           verbose = 1)

    gsearch.fit(X_train,y_train)


    results_xg = pd.DataFrame(gsearch.cv_results_)
    results_xg.sort_values(by='rank_test_score', inplace=True)

    return gsearch.best_params_

# %%
hyperParameterTuning(x_train, y_train['life_expectancy'])
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_child_weight': 5,
#  'n_estimators': 500,
#  'objective': 'reg:squarederror',
#  'subsample': 0.7}

# %%
# Instantiation
xgb_model = xg.XGBRegressor(
        objective = 'reg:squarederror',
        colsample_bytree = 0.7,
        learning_rate = 0.1,
        max_depth = 5,
        min_child_weight = 5,
        n_estimators = 500,
        subsample = 0.7)

# Fitting the model
xgb_model.fit(x_train, y_train["life_expectancy"], verbose=False)

# Predict the model
pred = xgb_model.predict(x_test)

mse = mean_squared_error(y_test["life_expectancy"], pred)**(0.5)
print(mse)
a = r2_score(y_test["life_expectancy"], pred)
print(a)
# Out:
# 1.976790844724582
# 0.9500525916566019

# %%
from matplotlib import pyplot as plt

sorted_idx = xgb_model.feature_importances_.argsort()
plt.barh(col[sorted_idx], xgb_model.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")

plt.show()
